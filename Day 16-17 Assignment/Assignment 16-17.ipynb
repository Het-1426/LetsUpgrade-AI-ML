# %% [markdown]
# # Importing pands and required files for the Assignment..

# %%
import pandas as pd

# %%
cast = pd.read_csv("cast.csv")
cast
cast.head(3)
# Out:
#                  title  year      name   type        character     n
# 0       Closet Monster  2015  Buffy #1  actor          Buffy 4  31.0
# 1      Suuri illusioni  1985    Homo $  actor           Guests  22.0
# 2  Battle of the Sexes  2017   $hutter  actor  Bobby Riggs Fan  10.0

# %%
titles = pd.read_csv("titles.csv")
titles
titles.head(3)
# Out:
#                   title  year
# 0    Tasveer Mere Sanam  1996
# 1              Only You  1994
# 2  El pueblo del terror  1970

# %%
release_dates = pd.read_csv("release_dates.csv")
release_dates
release_dates.head(3)
# Out:
#                    title  year   country        date
# 0  #73, Shaanthi Nivaasa  2007     India  2007-06-15
# 1                  #BKKY  2016  Cambodia  2017-10-12
# 2                #Beings  2015   Romania  2015-01-29

# %% [markdown]
# # 1. How many movies are listed in the titles dataframe?

# %%
a = len(titles)
print("movies that are listed in titles dataset are:", a)
# Out:
# movies that are listed in titles dataset are: 244914

# %% [markdown]
# # 2.What are the earliest two films listed in the titles dataframe?

# %%
b = titles.sort_values(by=['year']).head(2)
print("Earlies 2 films in titles dataset are:\n", b)
# Out:
# Earlies 2 films in titles dataset are:
#                       title  year
# 193222          Miss Jerry  1894
# 51388   The Startled Lover  1898

# %% [markdown]
# # 3.How many movies have the title "Hamlet"?

# %%
print("Total number of movies that have title Hamlet are: ")
len(titles[titles['title']=='Hamlet'])
# Out:
# Total number of movies that have title Hamlet are:
# 20

# %% [markdown]
# # 4.How many movies are titled "North by Northwest"?

# %%
c = len(titles[titles['title']=='North by Northwest'])
print("Total number of movies that have title North by Northwest are: ", c)
# Out:
# Total number of movies that have title North by Northwest are:  1

# %% [markdown]
# # 5.When was the first movie titled "Hamlet" made?

# %%
print("The first movie titled Hamlet was made in the following year:")
titles[titles['title']=='Hamlet'].sort_values(by=['year']).head(1).year
# Out:
# The first movie titled Hamlet was made in the following year:
# 52521    1910
# Name: year, dtype: int64

# %% [markdown]
# # 6.List all of the "Treasure Island" movies from earliest to most recent.

# %%
print("List of all Treasure Island movies form earliest to most recent are:")
titles[titles['title']=='Treasure Island'].sort_values(by=['year'])
# Out:
# List of all Treasure Island movies form earliest to most recent are:
#                   title  year
# 55686   Treasure Island  1918
# 196514  Treasure Island  1920
# 141822  Treasure Island  1934
# 77354   Treasure Island  1950
# 65051   Treasure Island  1972
# 37238   Treasure Island  1973
# 173051  Treasure Island  1985
# 27076   Treasure Island  1999

# %% [markdown]
# # 7.How many movies were made in the year 1950?

# %%
d = len(titles[titles['year']==1950])
print("Total no.of movies that were made in year 1950 are: ", d)
# Out:
# Total no.of movies that were made in year 1950 are:  1113

# %% [markdown]
# # 8.How many movies were made in the year 1960?

# %%
e= len(titles[titles['year']==1960])
print("Total no.of movies that were made in year 1960 are: ", e)
# Out:
# Total no.of movies that were made in year 1960 are:  1549

# %% [markdown]
# # 9.How many movies were made from 1950 through 1959?

# %%
f = len(titles[(titles['year']>=1950)&(titles['year']<=1959)])
print("Total no.of movies that were made in year from 1950 to 1959 are: ", f)
# Out:
# Total no.of movies that were made in year from 1950 to 1959 are:  12934

# %% [markdown]
# # 10.In what years has a movie titled "Batman" been released?

# %%
print("Followin years Batman movie was released: ")
(titles[(titles['title']=='Batman')]).head()
# Out:
# Followin years Batman movie was released:
#          title  year
# 39349   Batman  1943
# 240896  Batman  1989

# %% [markdown]
# # 11.How many roles were there in the movie "Inception"?

# %%
print("Total number of roles that were in the movie Inception are:")
print(len(cast[cast['title']=='Inception'].type))
print("The roles are displayed below:")
cast[cast['title']=='Inception'].head()
# Out:
# Total number of roles that were in the movie Inception are:
# 78
# The roles are displayed below:
#             title  year                  name   type              character  \
# 98153   Inception  2010  Michael (III) August  actor          LAX Passenger
# 149008  Inception  2010          Peter Basham  actor  Fischer's Jet Captain
# 183937  Inception  2010          Tom Berenger  actor               Browning
# 197877  Inception  2010              Ken Bhan  actor       Mombasan Gambler
# 260128  Inception  2010        Virgile Bramly  actor         Bridge Sub Con
#
#            n
# 98153    NaN
# 149008  44.0
# 183937   8.0
# 197877   NaN
# 260128  29.0

# %% [markdown]
# # 12.How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
print("The number of roles in the movie Inception not ranked by n value are:")
print(len(cast[(cast['title']=='Inception')&(cast['n'].isnull()==True)].type))
print("The roles are displayed below:")
cast[(cast['title']=='Inception')&(cast['n'].isnull()==True)]
# Out:
# The number of roles in the movie Inception not ranked by n value are:
# 27
# The roles are displayed below:
#              title  year                     name     type  \
# 98153    Inception  2010     Michael (III) August    actor
# 197877   Inception  2010                 Ken Bhan    actor
# 374661   Inception  2010            John Ceallach    actor
# 497161   Inception  2010             Garvin Cross    actor
# 684098   Inception  2010            Seve Esposito    actor
# 690634   Inception  2010      Marcus (II) Everett    actor
# 707642   Inception  2010  Zachary Christopher Fay    actor
# 836295   Inception  2010        Daniel Girondeaud    actor
# 1006636  Inception  2010          Andrew Hoagland    actor
# 1095095  Inception  2010          Charles Jarrell    actor
# 1108755  Inception  2010            Seong-hwan Jo    actor
# 1120184  Inception  2010          Alonzo F. Jones    actor
# 1189066  Inception  2010               Mobin Khan    actor
# ...

# %% [markdown]
# # 13.But how many roles in the movie "Inception" did receive an "n" value ?

# %%
print("The number of roles in the movie Inception ranked by n value are:")
print(len(cast[(cast['title']=='Inception')&(cast['n'].isnull()==False)].type))
print("The roles are displayed below:")
cast[(cast['title']=='Inception')&(cast['n'].isnull()==False)]
# Out:
# The number of roles in the movie Inception ranked by n value are:
# 51
# The roles are displayed below:
#              title  year                  name     type  \
# 149008   Inception  2010          Peter Basham    actor
# 183937   Inception  2010          Tom Berenger    actor
# 260128   Inception  2010        Virgile Bramly    actor
# 326745   Inception  2010         Michael Caine    actor
# 333415   Inception  2010          Earl Cameron    actor
# 433867   Inception  2010         Nicolas Clerc    actor
# 444385   Inception  2010        Adam (IV) Cole    actor
# 517227   Inception  2010    Jean-Michel Dagory    actor
# 590576   Inception  2010     Leonardo DiCaprio    actor
# 709436   Inception  2010             Russ Fega    actor
# 737322   Inception  2010      Mark Fleischmann    actor
# 807795   Inception  2010        Michael Gaston    actor
# 812135   Inception  2010       Johnathan Geare    actor
# 832083   Inception  2010         Carl Gilliard    actor
# ...

# %% [markdown]
# # 14.Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
print("The cast of North by Northwest in their correct n-value order value with n values are:")
print(cast[(cast['title']=="North by Northwest")&(cast['n'].isnull()==False)].sort_values(by=['n']).name)
print("The cast is displayed below:")
cast[(cast['title']=="North by Northwest")&(cast['n'].isnull()==False)].sort_values(by=['n']).T
# Out:
# The cast of North by Northwest in their correct n-value order value with n values are:
# 871426               Cary Grant
# 3518333         Eva Marie Saint
# 1457165             James Mason
# 3157232     Jessie Royce Landis
# 356707           Leo G. Carroll
# 3048272    Josephine Hutchinson
# 1695173             Philip Ober
# 1275337           Martin Landau
# 2447081           Adam Williams
# 1811387            Edward Platt
# 665768        Robert Ellenstein
# 2295714            Les Tremayne
# 464736          Philip Coolidge
# 1508344           Patrick McVey
# 206471             Edward Binns
# 1384780               Ken Lynch
# Name: name, dtype: object
# The cast is displayed below:
#                       871426              3518333             1457165  \
# title      North by Northwest  North by Northwest  North by Northwest
# year                     1959                1959                1959
# name               Cary Grant     Eva Marie Saint         James Mason
# ...

# %% [markdown]
# # 15.Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
print("The entire cast of 1972 film Seluth order by n value is:")
print((cast[(cast['title']=="Sleuth")&(cast['year']==1972)]).sort_values(by=['n']).name)
print("The entire cast is displayed below:")
cast[(cast['title']=="Sleuth")&(cast['year']==1972)].sort_values(by=['n'])
# Out:
# The entire cast of 1972 film Seluth order by n value is:
# 1705394      Laurence Olivier
# 326773          Michael Caine
# 373876         Alec Cawthorne
# 1465483    John (II) Matthews
# 2724553    Eve (III) Channing
# 1448690          Teddy Martin
# Name: name, dtype: object
# The entire cast is displayed below:
#           title  year                name     type  \
# 1705394  Sleuth  1972    Laurence Olivier    actor
# 326773   Sleuth  1972       Michael Caine    actor
# 373876   Sleuth  1972      Alec Cawthorne    actor
# 1465483  Sleuth  1972  John (II) Matthews    actor
# 2724553  Sleuth  1972  Eve (III) Channing  actress
# 1448690  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1705394                 Andrew Wyke  1.0
# 326773                  Milo Tindle  2.0
# 373876            Inspector Doppler  3.0
# 1465483  Detective Sergeant Tarrant  4.0
# 2724553             Marguerite Wyke  5.0
# 1448690      Police Constable Higgs  6.0

# %% [markdown]
# # 16.Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth"

# %%
print("The entire cast of 2007 version of movie Sleuth: ")
print(cast[(cast['title']=="Sleuth")&(cast['year']==2007)].sort_values(by=['n']).name)
print("The entire cast is displayed below:")
cast[(cast['title']=="Sleuth")&(cast['year']==2007)].sort_values(by=['n'])
# Out:
# The entire cast of 2007 version of movie Sleuth:
# 326774           Michael Caine
# 1293634               Jude Law
# 1805907          Harold Pinter
# 260242         Kenneth Branagh
# 373877     Alec (II) Cawthorne
# 2724552      Eve (II) Channing
# 3370424      Carmel O'Sullivan
# Name: name, dtype: object
# The entire cast is displayed below:
#           title  year                 name     type          character    n
# 326774   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1293634  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1805907  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 260242   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 373877   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2724552  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3370424  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %% [markdown]
# # 17.How many roles were credited in the silent 1921 version of Hamlet?

# %%
print("The number of roles that were credited in the silent 1921 version of Hamlet are:")
print(len(cast[(cast['title']=='Hamlet')&(cast['year']==1921)]))
print("The roles are displayed below:")
cast[(cast['title']=='Hamlet')&(cast['year']==1921)]
# Out:
# The number of roles that were credited in the silent 1921 version of Hamlet are:
# 9
# The roles are displayed below:
#           title  year                    name     type         character    n
# 7789     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 458904   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 555034   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1135279  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 2185558  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2375993  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2664423  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 3062023  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 3355176  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %% [markdown]
# # 18.How many roles were credited in Branagh’s 1996 Hamlet?

# %%
print("Roles that were credited in Branagh's 1996 Hamlet movie are: ")
print(len(cast[(cast['title']=='Hamlet')&(cast['year']==1996)]))
print("The roles are displayed below:")
cast[(cast['title']=='Hamlet')&(cast['year']==1996)]
# Out:
# Roles that were credited in Branagh's 1996 Hamlet movie are:
# 54
# The roles are displayed below:
#           title  year                    name     type  \
# 1731     Hamlet  1996              Riz Abbasi    actor
# 95861    Hamlet  1996    Richard Attenborough    actor
# 158642   Hamlet  1996     Simon Russell Beale    actor
# 214473   Hamlet  1996         David (V) Blair    actor
# 219554   Hamlet  1996           Brian Blessed    actor
# 250773   Hamlet  1996      Christopher Bowles    actor
# 260225   Hamlet  1996         Kenneth Branagh    actor
# 272749   Hamlet  1996          Richard Briers    actor
# 294652   Hamlet  1996          Michael Bryant    actor
# 319501   Hamlet  1996            Peter Bygott    actor
# 344365   Hamlet  1996       Kenneth W Caravan    actor
# 500916   Hamlet  1996           Billy Crystal    actor
# 518572   Hamlet  1996           Charles Daish    actor
# 576147   Hamlet  1996        G?rard Depardieu    actor
# ...

# %% [markdown]
# # 19.How many "Hamlet" roles have been listed in all film credits through history?

# %%
print("The number of Hamlet roles that have been listed in all film credits throughout the history are:")
print(len(cast[(cast['title']=='Hamlet')]))
print("Following are the roles that were credited:")
cast[(cast['title']=='Hamlet')]
# Out:
# The number of Hamlet roles that have been listed in all film credits throughout the history are:
# 342
# Following are the roles that were credited:
#           title  year              name     type              character     n
# 1731     Hamlet  1996        Riz Abbasi    actor  Attendant to Claudius   1.0
# 7789     Hamlet  1921  Fritz Achterberg    actor            Fortinbras,   9.0
# 11728    Hamlet  2009      Hayden Adams    actor                Laertes   7.0
# 11729    Hamlet  2009      Hayden Adams    actor                 Player   7.0
# 14493    Hamlet  1913       Eric Adeney    actor               Reynaldo  14.0
# ...         ...   ...               ...      ...                    ...   ...
# 3673234  Hamlet  1969    Jennifer Tudor  actress             Court lady  23.0
# 3697397  Hamlet  2000      Diane Venora  actress               Gertrude   3.0
# 3728751  Hamlet  1996     Perdita Weeks  actress          Second Player  44.0
# ...

# %% [markdown]
# # 20.How many people have played an "Ophelia"?

# %%
print("The number of people who played Ophelia are:")
print(len(cast[cast['character']=='Ophelia']))
cast[cast['character']=='Ophelia'].name
# Out:
# The number of people who played Ophelia are:
# 117
# 248251              Amy Bourque
# 410247           Josie Chisholm
# 470859          Crystal Cordero
# 866334            Lucas Grabeel
# 1364457     Catherine (IV) Lord
#                    ...
# 3722298         Marsha Warfield
# 3723039    Jennifer Lynn Warren
# 3733637         Katie (II) West
# 3748118       Helen (IV) Wilson
# 3751232            Kate Winslet
# Name: name, Length: 117, dtype: object

# %% [markdown]
# # 21.How many people have played a role called "The Dude"?

# %%
print("The number of people who played The Dude are:")
print(len(cast[cast['character']=='The Dude']))
cast[cast['character']=='The Dude'].name
# Out:
# The number of people who played The Dude are:
# 19
# 272161             Jeff Bridges
# 339389              Jordan Cann
# 498660            Scott Crowell
# 570128           Chris DeMarcus
# 610791              Mike Donlin
# 629473           Devin The Dude
# 855976       Michael D. Goodwin
# 1089444     Matthew (XIX) James
# 1138933      Christopher Kadish
# 1367230        Jason Loughridge
# 1386561             Steve Lyons
# 1512572          Mark Alan Meek
# 1540933             Jerry Miley
# 1784519        House Peters Jr.
# 1824744    Thomas (VIII) Porter
# 1838960         Jason Priestley
# 2202150            Bobby Styles
# 2336261         Dick Van Patten
# 2419271              Joel Weiss
# Name: name, dtype: object

# %% [markdown]
# # 22.How many people have played a role called "The Stranger"?

# %%
print("The number of people who played The Stranger are:")
print(len(cast[cast['character']=='The Stranger']))
print("The names are listed below:")
cast[cast['character']=='The Stranger'].name
# Out:
# The number of people who played The Stranger are:
# 212
# The names are listed below:
# 25954      Hassan Mutlag Al-Maraiyeh
# 35748           Vincent H. Alexander
# 46418                   Terral Altom
# 67421                   Tony Anthony
# 67424                   Tony Anthony
#                      ...
# 3219011                  Ethel Lynne
# 3405700               Rosa Maria Paz
# 3427715             Angela Pleasence
# 3567516              Dorinea Shirley
# 3746949    Kerry (II) Willison-Parry
# Name: name, Length: 212, dtype: object

# %% [markdown]
# # 23. How many roles has Sidney Poitier played throughout his career?

# %%
print("The number of roles played by Sidney Poitier are:")
print(len(cast[cast['name']=='Sidney Poitier']))
cast[cast['name']=='Sidney Poitier']
# Out:
# The number of roles played by Sidney Poitier are:
# 43
#                                 title  year            name   type  \
# 1816209               A Patch of Blue  1965  Sidney Poitier  actor
# 1816210         A Piece of the Action  1977  Sidney Poitier  actor
# 1816211           A Raisin in the Sun  1961  Sidney Poitier  actor
# 1816212               A Warm December  1973  Sidney Poitier  actor
# 1816213             All the Young Men  1960  Sidney Poitier  actor
# 1816214                Band of Angels  1957  Sidney Poitier  actor
# 1816215             Blackboard Jungle  1955  Sidney Poitier  actor
# 1816216                  Brother John  1971  Sidney Poitier  actor
# 1816217         Buck and the Preacher  1972  Sidney Poitier  actor
# 1816218      Cry, the Beloved Country  1951  Sidney Poitier  actor
# 1816219                Duel at Diablo  1966  Sidney Poitier  actor
# 1816220              Edge of the City  1957  Sidney Poitier  actor
# ...

# %% [markdown]
# # 24. How many roles has Judi Dench played?

# %%
print("The number of roles played by Judi Dench are:")
print(len(cast[cast['name']=='Judi Dench']))
print("The roles are displayed below:")
cast[cast['name']=='Judi Dench']
# Out:
# The number of roles played by Judi Dench are:
# 55
# The roles are displayed below:
#                                                title  year        name  \
# 2814206                        84 Charing Cross Road  1987  Judi Dench
# 2814207                            A Handful of Dust  1988  Judi Dench
# 2814208                    A Midsummer Night's Dream  1968  Judi Dench
# 2814209                           A Room with a View  1985  Judi Dench
# 2814210                            A Study in Terror  1965  Judi Dench
# 2814211       Angelina Ballerina: Angelina Sets Sail  2006  Judi Dench
# 2814212      Branagh Theatre Live: The Winter's Tale  2015  Judi Dench
# 2814213                                Casino Royale  2006  Judi Dench
# 2814214                                     Chocolat  2000  Judi Dench
# 2814215                                    Dead Cert  1974  Judi Dench
# 2814216                              Die Another Day  2002  Judi Dench
# ...

# %% [markdown]
# # 25.List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
print("The list of supporting roles played by Cary Grant in 1940's ordered by year are:")
cast[(cast['name']=='Cary Grant')&(cast['n']==2)&(cast['year']>=1940)&(cast['year']<=1949)].sort_values(by=['year'])
# Out:
# The list of supporting roles played by Cary Grant in 1940's ordered by year are:
#                    title  year        name   type    character    n
# 871423  My Favorite Wife  1940  Cary Grant  actor   Nick Arden  2.0
# 871433    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# # 26. List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
print(" List the leading roles that Cary Grant played in the 1940s ordered by year are:")
cast[(cast['name']=='Cary Grant')&(cast['n']==1)&(cast['year']>=1940)&(cast['year']<=1949)].sort_values(by=['year'])
# Out:
#  List the leading roles that Cary Grant played in the 1940s ordered by year are:
#                                        title  year        name   type  \
# 871448               The Howards of Virginia  1940  Cary Grant  actor
# 871407                       His Girl Friday  1940  Cary Grant  actor
# 871450                The Philadelphia Story  1940  Cary Grant  actor
# 871438                             Suspicion  1941  Cary Grant  actor
# 871452                  The Talk of the Town  1942  Cary Grant  actor
# 871429                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 871398                     Destination Tokyo  1943  Cary Grant  actor
# 871422                             Mr. Lucky  1943  Cary Grant  actor
# 871430                      Once Upon a Time  1944  Cary Grant  actor
# 871390                  Arsenic and Old Lace  1944  Cary Grant  actor
# 871425             None But the Lonely Heart  1944  Cary Grant  actor
# ...

# %% [markdown]
# # 27.How many roles were available for actors in the 1950s?

# %%
z = (len(cast[(cast['year']>=1950)&(cast['year']<=1959)&(cast['type']=='actor')].type))
print("The number of roles available for actors in 1950s are:", z)
# Out:
# The number of roles available for actors in 1950s are: 157738

# %% [markdown]
# # 28.How many roles were available for actresses in the 1950s?

# %%
w = (len(cast[(cast['year']>=1950)&(cast['year']<=1959)&(cast['type']=='actress')].type))
print("The number of roles available for actresses in 1950s are:", w)
# Out:
# The number of roles available for actresses in 1950s are: 57733

# %% [markdown]
# # 29.How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
leading = (len(cast[(cast['year']<=1980)&(cast['n']==1)].type))
print("The number of leading roles available from the beginning of film history through 1980 are: ", leading)
# Out:
# The number of leading roles available from the beginning of film history through 1980 are:  65140

# %% [markdown]
# # 30.How many non-leading roles were available through from the beginning of film history through 1980?

# %%
non_leading = (len(cast[(cast['year']<=1980)&(cast['n']!=1)].type))
print("The number of non-leading roles available from the beginning of film history through 1980 are: ", non_leading)
# Out:
# The number of non-leading roles available from the beginning of film history through 1980 are:  1117667

# %% [markdown]
# # 31.How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
minor  = (len(cast[(cast['year']==1980)&(cast['n'].isnull()==True)]))
print("The number of roles through 1980 that were minor enough and did not warrant a numeric n rank are: ", minor)
# Out:
# The number of roles through 1980 that were minor enough and did not warrant a numeric n rank are:  4466
